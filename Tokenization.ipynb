# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in d:\myprojects\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: click in d:\myprojects\.venv\lib\site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in d:\myprojects\.venv\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\myprojects\.venv\lib\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in d:\myprojects\.venv\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in d:\myprojects\.venv\lib\site-packages (from click->nltk) (0.4.6)

# %%
corpus="""Hello welcome, to Ravi prasad's NLP tutorials. 
Please do wathch the entire course! to become expert in NLP.
my name is Ravi
"""

# %%
print(corpus)
# Out:
# Hello welcome, to Ravi prasad's NLP tutorials.
# Please do wathch the entire course! to become expert in NLP.

# %%
#Tokenization
##Sentence-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
documents
# Out:
# ["Hello welcome, to Ravi prasad's NLP tutorials.",
#  'Please do wathch the entire course!',
#  'to become expert in NLP.']

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello welcome, to Ravi prasad's NLP tutorials.
# Please do wathch the entire course!
# to become expert in NLP.

# %%
##Tokenization
##Paragraph--->words
##sentence-->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Ravi',
#  'prasad',
#  "'s",
#  'NLP',
#  'tutorials',
#  '.',
#  'Please',
#  'do',
#  'wathch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', ',', 'to', 'Ravi', 'prasad', "'s", 'NLP', 'tutorials', '.']
# ['Please', 'do', 'wathch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Ravi',
#  'prasad',
#  "'",
#  's',
#  'NLP',
#  'tutorials',
#  '.',
#  'Please',
#  'do',
#  'wathch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Ravi',
#  'prasad',
#  "'s",
#  'NLP',
#  'tutorials.',
#  'Please',
#  'do',
#  'wathch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
